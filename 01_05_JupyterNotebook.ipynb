# %% [markdown]
# # Title
# ## Smaller Title

# %% [markdown]
# \begin{equation}
# e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i
# \end{equation}

# %%
print('Doing some data science!')
# Out:
# Doing some data science!

# %%
print(1 + 3)
# Out:
# 4

# %%
print('Aman')
# Out:
# Aman

# %%
a= 2
b=3 
print(a*b)
# Out:
# 6

# %%
a= [1,2,3]
z=a.reverse()
print(z)
b=[3,2,1]
print(b)
# Out:
# None
# [3, 2, 1]
