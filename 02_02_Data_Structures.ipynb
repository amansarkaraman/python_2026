# %% [markdown]
# # Data Structures

# %% [markdown]
# ## Lists

# %%
x='aman',
y='zaman',
l=x+y
print(l)
# Out:
# ('aman', 'zaman')

# %%
m = ['a','b','c',1,2]
print(m)
len(m)
print(m*2)
# Out:
# ['a', 'b', 'c', 1, 2]
# ['a', 'b', 'c', 1, 2, 'a', 'b', 'c', 1, 2]

# %%
my_list = [1,2,3,4,5]
print(my_list)
# Out:
# [1, 2, 3, 4, 5]

# %%
my_list=[1,2,[],[True,False]]

# %%
len(my_list)
# Out:
# 4

# %% [markdown]
# # Set

# %%
my_set = {1,2,3,4,5}
#print(my_set)
len(my_set)
#test_set={'a','b',1,2}
#print(test_set)
# Out:
# 5

# %%
type(test_set)
# Out:
# set

# %%
print(my_set)
# Out:
# {1, 2}

# %%
my_set = {1,1,2,2},
len(my_set),
print(my_set)
# Out:
# ({1, 2},)

# %%
[1,2] == [2,1]
# Out:
# False

# %%
{1,2,3} == {3,2,1,1,1}
# Out:
# True

# %% [markdown]
# ## Tuples

# %%
my_tuple = (1,2,3)

# tuple are different from sets and lists
# tuple is used for saving storage to save data
my_test_tupple = (1,4,5)
print (my_test_tupple)
len (my_test_tupple)
print (my_test_tupple*4)
# Out:
# (1, 4, 5)
# (1, 4, 5, 1, 4, 5, 1, 4, 5, 1, 4, 5)

# %%
len(my_tuple)
# Out:
# 3

# %%
(1,2) == (2,1)
{1,6} == {1,7}
# Out:
# False

# %%
#append is that which add value at the end of the list but append can't add value to a tuple
my_list.append(6)
print(my_list)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
my_tuple.append(4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 my_tuple.append(4)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %% [markdown]
# ## Dictionaries

# %%
#dictionary is a kind of value pair using dictionary we can give some value a descrption like bellow
my_dictionary = {
    'apple': 'A red fruit', 
    'bear': 'A scary animal'
}
test_dictiomnary={
    'tanzil' :'Comes form Barisal',
    'fardin' : 'Comes from Gazir'
}

print(test_dictiomnary)
# Out:
# {'tanzil': 'Comes form Barisal', 'fardin': 'Comes from Gazir'}

# %%
my_dictionary['apple']
test_dictiomnary['tanzil']
test_dictiomnary['fardin']
len(test_dictiomnary)
# Out:
# 2

# %%
my_dictionary = {
    'apple': 'A red fruit', 
    'bear': 'A scary animal',
    'apple': 'Sometimes a green fruit'
}

# %%
my_dictionary['apple']
# Out:
# 'Sometimes a green fruit'

# %%
test_my_dictionary_again = {
    'name': 'Md Aman',
    'age': 29,
    'maretial_status': 'Single'
}
print (test_my_dictionary_again)
test_my_dictionary_again['name']
print( 'My name is : ' + test_my_dictionary_again['name'])
print( 'And I am : ' + test_my_dictionary_again['maretial_status'])
print('I am ' + str(test_my_dictionary_again['age'])+ ' years old')
# Out:
# {'name': 'Md Aman', 'age': 29, 'maretial_status': 'Single'}
# My name is : Md Aman
# And I am : Single
# I am 29 years old
